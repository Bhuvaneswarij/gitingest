# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhuvaneswarij/gitingest/blob/main/LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ===============================
# SECTION 0: Install Dependencies
# ===============================
# !pip install -q numpy pandas scikit-learn tensorflow keras optuna shap matplotlib seaborn tqdm

# ===============================
# SECTION 1: Import Libraries
# ===============================
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import optuna
import shap
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

print("✅ Libraries imported successfully!")

# ===============================
# SECTION 2: Load or Generate Dataset
# ===============================
# Generate synthetic time series (replace with CSV if available)
np.random.seed(42)
data_length = 500
data = np.sin(np.arange(data_length) * 0.1) + np.random.normal(0, 0.1, data_length)
df = pd.DataFrame(data, columns=["value"])
print("Dataset shape:", df.shape)
df.head()

# ===============================
# SECTION 3: Scale Data
# ===============================
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df.values)

# ===============================
# SECTION 4: Create Sequences
# ===============================
SEQ_LEN = 8  # Can be tuned

def create_sequences(data, seq_len=SEQ_LEN):
    X, y = [], []
    for i in range(len(data) - seq_len):
        X.append(data[i:i+seq_len])
        y.append(data[i+seq_len])
    return np.array(X), np.array(y)

X, y = create_sequences(scaled_data)
print("X shape:", X.shape, "y shape:", y.shape)

# ===============================
# SECTION 5: Train/Test Split
# ===============================
split_idx = int(len(X) * 0.8)
X_train, X_test = X[:split_idx], X[split_idx:]
y_train, y_test = y[:split_idx], y[split_idx:]
print("Train shapes:", X_train.shape, y_train.shape)
print("Test shapes:", X_test.shape, y_test.shape)

# ===============================
# SECTION 6: Build LSTM Model Function
# ===============================
def build_model(hidden_units=50, input_shape=(SEQ_LEN, X.shape[2])):
    model = Sequential()
    model.add(LSTM(hidden_units, input_shape=input_shape))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')
    return model

# ===============================
# SECTION 7: Hyperparameter Tuning with Optuna
# ===============================
def objective(trial):
    hidden_units = trial.suggest_int("hidden_units", 10, 100)
    lr = trial.suggest_loguniform("lr", 1e-4, 1e-2)

    model = build_model(hidden_units=hidden_units)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr), loss='mse')
    model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=0)

    loss = model.evaluate(X_test, y_test, verbose=0)
    return loss

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=10)
print("✅ Best Hyperparameters:", study.best_params)

# ===============================
# SECTION 8: Train Final Model
# ===============================
best_params = study.best_params
final_model = build_model(hidden_units=best_params['hidden_units'])
final_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=best_params['lr']), loss='mse')
final_model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

# ===============================
# SECTION 9: Make Predictions & Evaluate
# ===============================
y_pred = final_model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred) ** 0.5
print(f"MAE: {mae:.4f}, RMSE: {rmse:.4f}")

# ===============================
# SECTION 10: SHAP Explainability (3D Fix Included)
# ===============================
# Flatten sequences for SHAP
X_train_flat = X_train.reshape(X_train.shape[0], -1)

# Wrapper function to reshape 2D -> 3D for LSTM
def model_predict_reshaped(X):
    X_reshaped = X.reshape(X.shape[0], SEQ_LEN, X.shape[1] // SEQ_LEN)
    return final_model.predict(X_reshaped)

# Create SHAP explainer using wrapper
explainer = shap.KernelExplainer(model_predict_reshaped, X_train_flat[:100])
shap_values = explainer.shap_values(X_train_flat[:10])

# SHAP summary plot
shap.summary_plot(shap_values, X_train_flat[:10])

# ===============================
# SECTION 11: Save Forecast Results
# ===============================
results = pd.DataFrame({
    'y_true': y_test.flatten(),
    'y_pred': y_pred.flatten()
})
results.to_csv("forecast_results.csv", index=False)
print("✅ Forecast results saved to forecast_results.csv")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 4.7 MB/s eta 0:00:00
# [I 2025-12-06 13:27:44,127] A new study created in memory with name: no-name-3655cc8e-dd83-43b0-993c-30a286362d37
# ✅ Libraries imported successfully!
# Dataset shape: (500, 1)
# X shape: (492, 8, 1) y shape: (492, 1)
# Train shapes: (393, 8, 1) (393, 1)
# Test shapes: (99, 8, 1) (99, 1)
# /tmp/ipython-input-2157728600.py:80: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform("lr", 1e-4, 1e-2)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# [I 2025-12-06 13:27:48,303] Trial 0 finished with value: 0.02242155745625496 and parameters: {'hidden_units': 90, 'lr': 0.00011858300675824884}. Best is trial 0 with value: 0.02242155745625496.
# [I 2025-12-06 13:27:51,740] Trial 1 finished with value: 0.013143405318260193 and parameters: {'hidden_units': 58, 'lr': 0.0011916266282564181}. Best is trial 1 with value: 0.013143405318260193.
# [I 2025-12-06 13:27:55,807] Trial 2 finished with value: 0.018826715648174286 and parameters: {'hidden_units': 67, 'lr': 0.00030913383143894765}. Best is trial 1 with value: 0.013143405318260193.
# [I 2025-12-06 13:27:59,268] Trial 3 finished with value: 0.013525559566915035 and parameters: {'hidden_units': 44, 'lr': 0.001192106263828703}. Best is trial 1 with value: 0.013143405318260193.
# [I 2025-12-06 13:28:02,785] Trial 4 finished with value: 0.010100561194121838 and parameters: {'hidden_units': 95, 'lr': 0.0012339212772361542}. Best is trial 4 with value: 0.010100561194121838.
# [I 2025-12-06 13:28:07,134] Trial 5 finished with value: 0.01073274202644825 and parameters: {'hidden_units': 19, 'lr': 0.001332389710160834}. Best is trial 4 with value: 0.010100561194121838.
# [I 2025-12-06 13:28:11,073] Trial 6 finished with value: 0.013255317695438862 and parameters: {'hidden_units': 86, 'lr': 0.0008983037217380272}. Best is trial 4 with value: 0.010100561194121838.
# [I 2025-12-06 13:28:14,364] Trial 7 finished with value: 0.012968159280717373 and parameters: {'hidden_units': 55, 'lr': 0.0011486350836606583}. Best is trial 4 with value: 0.010100561194121838.
# [I 2025-12-06 13:28:18,757] Trial 8 finished with value: 0.020165052264928818 and parameters: {'hidden_units': 50, 'lr': 0.00024095054915984702}. Best is trial 4 with value: 0.010100561194121838.
# [I 2025-12-06 13:28:22,212] Trial 9 finished with value: 0.00976472906768322 and parameters: {'hidden_units': 80, 'lr': 0.0012098615551492484}. Best is trial 9 with value: 0.00976472906768322.
# ✅ Best Hyperparameters: {'hidden_units': 80, 'lr': 0.0012098615551492484}
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2586
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0377
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0233
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0167
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0165
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0150
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0140
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0139
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0132
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0125
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0116
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0116
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0103
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0087
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0079
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0054
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0043
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0040
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0034
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0032
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0028
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0024
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0027
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0029
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0035
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0034
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0039
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0023
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0031
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0026
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0030
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0039
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# MAE: 0.0420, RMSE: 0.0543
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#   0%|          | 0/10 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 794/794 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# /tmp/ipython-input-2157728600.py:125: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values, X_train_flat[:10])
# /usr/local/lib/python3.12/dist-packages/shap/plots/_beeswarm.py:723: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   summary_legacy(
# ✅ Forecast results saved to forecast_results.csv
